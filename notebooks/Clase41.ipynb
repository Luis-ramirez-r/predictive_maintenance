# %%
import pandas as pd

# %% [markdown]
# ### XYZ1
#
# ![image.png](attachment:image.png)
#
#
# ### XYZ2
#
# ![image.png](attachment:image-2.png)
#
#
# ### XYZ3
#
# ![![image.png](attachment:image-3.png)](attachment:image-3.png)

# %%
df1 = pd.read_csv('/workspaces/predictive_maintenance/data/other/xyz1.csv', index_col=0)

# %%
df1 = df1.reset_index()
